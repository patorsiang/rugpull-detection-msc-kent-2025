# %% [markdown]
# # GCN

# %% [markdown]
# ## Load the data

# %%
import os
from pathlib import Path
import pickle

PATH = '' # os.path.join(Path.cwd().parents[2], 'data/processed/ir_gigahorse')

with open(os.path.join(PATH, "graphs_with_labels.pkl"), "rb") as f:
    graphs, labels = pickle.load(f)

# %% [markdown]
# ### sample

# %%
import networkx as nx
import matplotlib.pyplot as plt

for i, (graph, label) in enumerate(zip(graphs, labels)):
    nx.draw(graph, with_labels=True, node_color='lightblue', node_size=200, edge_color='gray', font_size=5)
    plt.title(f"Graph {i} with Labels: mint:{label['mint']}, leak: {label['mint']}, limit: {label['limit']}")
    plt.tight_layout()
    plt.show()
    if i == 2:
        break
# Out:
# /tmp/ipython-input-2-3026701571.py:7: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# ## Install required packages.

# %%
import os
import torch
os.environ['TORCH'] = torch.__version__
os.environ['PYTHONWARNINGS'] = "ignore"
print(torch.__version__)
# !pip install torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install git+https://github.com/pyg-team/pytorch_geometric.git
# Out:
# 2.6.0+cu124
# Looking in links: https://data.pyg.org/whl/torch-2.6.0+cu124.html
# Collecting torch-scatter
#   Downloading https://data.pyg.org/whl/torch-2.6.0%2Bcu124/torch_scatter-2.1.2%2Bpt26cu124-cp311-cp311-linux_x86_64.whl (10.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 73.5 MB/s eta 0:00:00
# Installing collected packages: torch-scatter
# Successfully installed torch-scatter-2.1.2+pt26cu124
# Looking in links: https://data.pyg.org/whl/torch-2.6.0+cu124.html
# Collecting torch-sparse
#   Downloading https://data.pyg.org/whl/torch-2.6.0%2Bcu124/torch_sparse-0.6.18%2Bpt26cu124-cp311-cp311-linux_x86_64.whl (5.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 22.8 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from torch-sparse) (1.15.3)
# Requirement already satisfied: numpy<2.5,>=1.23.5 in /usr/local/lib/python3.11/dist-packages (from scipy->torch-sparse) (2.0.2)
# Installing collected packages: torch-sparse
# Successfully installed torch-sparse-0.6.18+pt26cu124
# Collecting git+https://github.com/pyg-team/pytorch_geometric.git
#   Cloning https://github.com/pyg-team/pytorch_geometric.git to /tmp/pip-req-build-jtqjla2m
#   Running command git clone --filter=blob:none --quiet https://github.com/pyg-team/pytorch_geometric.git /tmp/pip-req-build-jtqjla2m
#   Resolved https://github.com/pyg-team/pytorch_geometric.git to commit ab6037b93077ca936a92b1a5ae876403e30cde0c
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from torch-geometric==2.7.0) (3.11.15)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch-geometric==2.7.0) (2025.3.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch-geometric==2.7.0) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torch-geometric==2.7.0) (2.0.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.11/dist-packages (from torch-geometric==2.7.0) (5.9.5)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.11/dist-packages (from torch-geometric==2.7.0) (3.2.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from torch-geometric==2.7.0) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from torch-geometric==2.7.0) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from torch-geometric==2.7.0) (3.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch-geometric==2.7.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch-geometric==2.7.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch-geometric==2.7.0) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch-geometric==2.7.0) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch-geometric==2.7.0) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch-geometric==2.7.0) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch-geometric==2.7.0) (1.20.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch-geometric==2.7.0) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->torch-geometric==2.7.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->torch-geometric==2.7.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->torch-geometric==2.7.0) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->torch-geometric==2.7.0) (2025.7.9)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.11/dist-packages (from aiosignal>=1.1.2->aiohttp->torch-geometric==2.7.0) (4.14.1)
# Building wheels for collected packages: torch-geometric
#   Building wheel for torch-geometric (pyproject.toml) ... done
#   Created wheel for torch-geometric: filename=torch_geometric-2.7.0-py3-none-any.whl size=1234809 sha256=8523186df563a846c2af4e0acb05252793a110be6cf97b4bbf62760902cfa397
#   Stored in directory: /tmp/pip-ephem-wheel-cache-367d4rmb/wheels/93/bb/85/bfec4ee59b2563f74ec87cc2c91c6a4d3e40d3dcdec8ee5afe
# Successfully built torch-geometric
# Installing collected packages: torch-geometric
# Successfully installed torch-geometric-2.7.0

# %%
def extract_graph_features(G):
    return {
        "num_nodes": G.number_of_nodes(),
        "num_edges": G.number_of_edges(),
        "avg_degree": sum(dict(G.degree()).values()) / G.number_of_nodes(),
        "density": nx.density(G),
        "connected_components": nx.number_weakly_connected_components(G),
        "avg_clustering": nx.average_clustering(G.to_undirected())
    }

# %%
import torch
from torch_geometric.utils import from_networkx

dataset = []

for graph, label in zip(graphs, labels):
    data = from_networkx(graph)
    label_value = [l for l in label.values()]
    features = extract_graph_features(graph)
    degrees = torch.tensor([d for _, d in graph.degree()], dtype=torch.float).unsqueeze(1)

    # Concatenate node degrees with graph-level features for each node
    graph_features_tensor = torch.tensor(list(features.values()), dtype=torch.float).unsqueeze(0).repeat(data.num_nodes, 1)
    data.x = torch.cat([degrees, graph_features_tensor], dim=1)


    data.y = torch.tensor(label_value, dtype=torch.float).unsqueeze(0)
    # data.x = torch.tensor([d for _, d in graph.degree()]+ list(features.values()), dtype=torch.float).unsqueeze(1)
    # data.x = degrees
    print(data)
    dataset.append(data)
# Out:
# Data(edge_index=[2, 1652], opcode=[1653], num_nodes=1653, x=[1653, 7], y=[1, 3])
# Data(edge_index=[2, 2691], opcode=[2692], num_nodes=2692, x=[2692, 7], y=[1, 3])
# Data(edge_index=[2, 6378], opcode=[6379], num_nodes=6379, x=[6379, 7], y=[1, 3])
# Data(edge_index=[2, 1636], opcode=[1637], num_nodes=1637, x=[1637, 7], y=[1, 3])
# Data(edge_index=[2, 3680], opcode=[3681], num_nodes=3681, x=[3681, 7], y=[1, 3])
# Data(edge_index=[2, 4557], opcode=[4558], num_nodes=4558, x=[4558, 7], y=[1, 3])
# Data(edge_index=[2, 2689], opcode=[2690], num_nodes=2690, x=[2690, 7], y=[1, 3])
# Data(edge_index=[2, 2581], opcode=[2582], num_nodes=2582, x=[2582, 7], y=[1, 3])
# Data(edge_index=[2, 5948], opcode=[5949], num_nodes=5949, x=[5949, 7], y=[1, 3])
# Data(edge_index=[2, 4676], opcode=[4677], num_nodes=4677, x=[4677, 7], y=[1, 3])
# Data(edge_index=[2, 4473], opcode=[4474], num_nodes=4474, x=[4474, 7], y=[1, 3])
# Data(edge_index=[2, 4128], opcode=[4129], num_nodes=4129, x=[4129, 7], y=[1, 3])
# Data(edge_index=[2, 66], opcode=[67], num_nodes=67, x=[67, 7], y=[1, 3])
# Data(edge_index=[2, 2688], opcode=[2689], num_nodes=2689, x=[2689, 7], y=[1, 3])
# Data(edge_index=[2, 2093], opcode=[2094], num_nodes=2094, x=[2094, 7], y=[1, 3])
# Data(edge_index=[2, 8703], opcode=[8704], num_nodes=8704, x=[8704, 7], y=[1, 3])
# Data(edge_index=[2, 3528], opcode=[3529], num_nodes=3529, x=[3529, 7], y=[1, 3])
# Data(edge_index=[2, 1633], opcode=[1634], num_nodes=1634, x=[1634, 7], y=[1, 3])
# Data(edge_index=[2, 3888], opcode=[3889], num_nodes=3889, x=[3889, 7], y=[1, 3])
# Data(edge_index=[2, 2103], opcode=[2104], num_nodes=2104, x=[2104, 7], y=[1, 3])
# Data(edge_index=[2, 5815], opcode=[5816], num_nodes=5816, x=[5816, 7], y=[1, 3])
# Data(edge_index=[2, 6036], opcode=[6037], num_nodes=6037, x=[6037, 7], y=[1, 3])
# Data(edge_index=[2, 23], opcode=[24], num_nodes=24, x=[24, 7], y=[1, 3])
# Data(edge_index=[2, 339], opcode=[340], num_nodes=340, x=[340, 7], y=[1, 3])
# Data(edge_index=[2, 2438], opcode=[2439], num_nodes=2439, x=[2439, 7], y=[1, 3])
# Data(edge_index=[2, 4023], opcode=[4024], num_nodes=4024, x=[4024, 7], y=[1, 3])
# Data(edge_index=[2, 8444], opcode=[8445], num_nodes=8445, x=[8445, 7], y=[1, 3])
# Data(edge_index=[2, 4105], opcode=[4106], num_nodes=4106, x=[4106, 7], y=[1, 3])
# Data(edge_index=[2, 1623], opcode=[1624], num_nodes=1624, x=[1624, 7], y=[1, 3])
# Data(edge_index=[2, 1557], opcode=[1558], num_nodes=1558, x=[1558, 7], y=[1, 3])
# Data(edge_index=[2, 2098], opcode=[2099], num_nodes=2099, x=[2099, 7], y=[1, 3])
# Data(edge_index=[2, 4381], opcode=[4382], num_nodes=4382, x=[4382, 7], y=[1, 3])
# Data(edge_index=[2, 1424], opcode=[1425], num_nodes=1425, x=[1425, 7], y=[1, 3])
# Data(edge_index=[2, 3241], opcode=[3242], num_nodes=3242, x=[3242, 7], y=[1, 3])
# Data(edge_index=[2, 3834], opcode=[3835], num_nodes=3835, x=[3835, 7], y=[1, 3])
# Data(edge_index=[2, 2097], opcode=[2098], num_nodes=2098, x=[2098, 7], y=[1, 3])
# Data(edge_index=[2, 2823], opcode=[2824], num_nodes=2824, x=[2824, 7], y=[1, 3])
# Data(edge_index=[2, 2363], opcode=[2364], num_nodes=2364, x=[2364, 7], y=[1, 3])
# Data(edge_index=[2, 4176], opcode=[4177], num_nodes=4177, x=[4177, 7], y=[1, 3])
# Data(edge_index=[2, 5041], opcode=[5042], num_nodes=5042, x=[5042, 7], y=[1, 3])
# Data(edge_index=[2, 15850], opcode=[15851], num_nodes=15851, x=[15851, 7], y=[1, 3])
# Data(edge_index=[2, 4757], opcode=[4758], num_nodes=4758, x=[4758, 7], y=[1, 3])
# Data(edge_index=[2, 2841], opcode=[2842], num_nodes=2842, x=[2842, 7], y=[1, 3])
# Data(edge_index=[2, 7574], opcode=[7575], num_nodes=7575, x=[7575, 7], y=[1, 3])
# Data(edge_index=[2, 4750], opcode=[4751], num_nodes=4751, x=[4751, 7], y=[1, 3])
# Data(edge_index=[2, 5559], opcode=[5560], num_nodes=5560, x=[5560, 7], y=[1, 3])
# Data(edge_index=[2, 6722], opcode=[6723], num_nodes=6723, x=[6723, 7], y=[1, 3])
# Data(edge_index=[2, 1627], opcode=[1628], num_nodes=1628, x=[1628, 7], y=[1, 3])
# Data(edge_index=[2, 4768], opcode=[4769], num_nodes=4769, x=[4769, 7], y=[1, 3])
# Data(edge_index=[2, 262], opcode=[263], num_nodes=263, x=[263, 7], y=[1, 3])
# Data(edge_index=[2, 7467], opcode=[7468], num_nodes=7468, x=[7468, 7], y=[1, 3])
# Data(edge_index=[2, 3361], opcode=[3362], num_nodes=3362, x=[3362, 7], y=[1, 3])
# Data(edge_index=[2, 9549], opcode=[9550], num_nodes=9550, x=[9550, 7], y=[1, 3])
# Data(edge_index=[2, 8704], opcode=[8705], num_nodes=8705, x=[8705, 7], y=[1, 3])
# Data(edge_index=[2, 4090], opcode=[4091], num_nodes=4091, x=[4091, 7], y=[1, 3])
# Data(edge_index=[2, 2362], opcode=[2363], num_nodes=2363, x=[2363, 7], y=[1, 3])
# Data(edge_index=[2, 3586], opcode=[3587], num_nodes=3587, x=[3587, 7], y=[1, 3])
# Data(edge_index=[2, 3351], opcode=[3352], num_nodes=3352, x=[3352, 7], y=[1, 3])
# Data(edge_index=[2, 10017], opcode=[10018], num_nodes=10018, x=[10018, 7], y=[1, 3])
# Data(edge_index=[2, 4826], opcode=[4827], num_nodes=4827, x=[4827, 7], y=[1, 3])
# Data(edge_index=[2, 1537], opcode=[1538], num_nodes=1538, x=[1538, 7], y=[1, 3])
# Data(edge_index=[2, 1543], opcode=[1544], num_nodes=1544, x=[1544, 7], y=[1, 3])
# Data(edge_index=[2, 9258], opcode=[9259], num_nodes=9259, x=[9259, 7], y=[1, 3])
# Data(edge_index=[2, 4772], opcode=[4773], num_nodes=4773, x=[4773, 7], y=[1, 3])
# Data(edge_index=[2, 4092], opcode=[4093], num_nodes=4093, x=[4093, 7], y=[1, 3])
# Data(edge_index=[2, 4095], opcode=[4096], num_nodes=4096, x=[4096, 7], y=[1, 3])
# Data(edge_index=[2, 3974], opcode=[3975], num_nodes=3975, x=[3975, 7], y=[1, 3])

# %%
from torch_geometric.data import DataLoader

# Data Loader
loader = DataLoader(dataset, batch_size=4, shuffle=True)
# Out:
# /tmp/ipython-input-6-1246845923.py:4: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   loader = DataLoader(dataset, batch_size=4, shuffle=True)

# %%
for batch in loader:
    print(batch)
    print(batch.x.shape, batch.y.shape)
    break
# Out:
# DataBatch(edge_index=[2, 19212], opcode=[4], num_nodes=19216, x=[19216, 7], y=[4, 3], batch=[19216], ptr=[5])
# torch.Size([19216, 7]) torch.Size([4, 3])

# %%
import numpy as np
from sklearn.metrics import f1_score

def tune_thresholds(y_true, y_pred_prob, metric='f1'):
    y_true = np.asarray(y_true)          # Fix: convert to NumPy
    y_pred_prob = np.asarray(y_pred_prob)

    best_thresholds = []
    best_scores = []

    for i in range(y_true.shape[1]):
        label_true = y_true[:, i]
        label_probs = y_pred_prob[:, i]  # Fix here too

        thresholds = np.linspace(0.0, 1.0, 101)
        scores = []

        for t in thresholds:
            label_pred = (label_probs >= t).astype(int)
            if metric == 'f1':
                score = f1_score(label_true, label_pred, zero_division=0)
            scores.append(score)

        best_t = thresholds[np.argmax(scores)]
        best_score = np.max(scores)

        best_thresholds.append(best_t)
        best_scores.append(best_score)

        print(f"Label {i}: Best threshold = {best_t:.2f}, Best {metric} = {best_score:.4f}")

    return best_thresholds, best_scores

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GCNConv, global_mean_pool
from torch_geometric.loader import DataLoader
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

# Define the GNN Model
class MultiLabelGCN(nn.Module):
    def __init__(self, in_channels, hidden_channels, num_labels):
        super(MultiLabelGCN, self).__init__()
        self.conv1 = GCNConv(in_channels, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, hidden_channels)
        self.lin = nn.Linear(hidden_channels, num_labels)

    def forward(self, x, edge_index, batch):
        x = F.relu(self.conv1(x, edge_index))
        x = F.relu(self.conv2(x, edge_index))
        x = global_mean_pool(x, batch)
        x = torch.sigmoid(self.lin(x))  # Multi-label sigmoid activation
        return x

# Split your dataset
train_data, test_data = train_test_split(dataset, test_size=0.2, random_state=42)

train_loader = DataLoader(train_data, batch_size=8, shuffle=True)
test_loader = DataLoader(test_data, batch_size=8, shuffle=False)

# Initialize Model, Loss, Optimizer
# in_channels should be the number of features per node now.
model = MultiLabelGCN(in_channels=7, hidden_channels=64, num_labels=3)
criterion = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
# Training Loop
for epoch in range(1, 101):
    model.train()
    total_loss = 0
    for batch in train_loader:
        optimizer.zero_grad()
        out = model(batch.x, batch.edge_index, batch.batch)
        loss = criterion(out, batch.y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    print(f"Epoch {epoch}, Loss: {total_loss/len(train_loader):.4f}")
# Out:
# Epoch 1, Loss: 34.9977
# Epoch 2, Loss: 57.6265
# Epoch 3, Loss: 63.5471
# Epoch 4, Loss: 64.6491
# Epoch 5, Loss: 62.9417
# Epoch 6, Loss: 63.5687
# Epoch 7, Loss: 63.5958
# Epoch 8, Loss: 63.2038
# Epoch 9, Loss: 62.8118
# Epoch 10, Loss: 63.4598
# Epoch 11, Loss: 62.9180
# Epoch 12, Loss: 38.5906
# Epoch 13, Loss: 28.5762
# Epoch 14, Loss: 28.2180
# Epoch 15, Loss: 28.2176
# Epoch 16, Loss: 28.9318
# Epoch 17, Loss: 27.8603
# Epoch 18, Loss: 27.8603
# Epoch 19, Loss: 28.5764
# Epoch 20, Loss: 27.1460
# Epoch 21, Loss: 27.8602
# Epoch 22, Loss: 28.5745
# Epoch 23, Loss: 27.5031
# Epoch 24, Loss: 28.5745
# Epoch 25, Loss: 28.5745
# Epoch 26, Loss: 28.9316
# Epoch 27, Loss: 29.2888
# Epoch 28, Loss: 27.8602
# Epoch 29, Loss: 30.0030
# Epoch 30, Loss: 29.6459
# Epoch 31, Loss: 28.2173
# Epoch 32, Loss: 27.1458
# Epoch 33, Loss: 27.1458
# Epoch 34, Loss: 27.5030
# Epoch 35, Loss: 28.2172
# Epoch 36, Loss: 28.5744
# Epoch 37, Loss: 28.9315
# Epoch 38, Loss: 28.2172
# Epoch 39, Loss: 28.2172
# Epoch 40, Loss: 28.5743
# Epoch 41, Loss: 28.9315
# Epoch 42, Loss: 28.2172
# Epoch 43, Loss: 28.9315
# Epoch 44, Loss: 28.5743
# Epoch 45, Loss: 27.5029
# Epoch 46, Loss: 28.2171
# Epoch 47, Loss: 28.5743
# Epoch 48, Loss: 29.2885
# Epoch 49, Loss: 29.2885
# Epoch 50, Loss: 28.2188
# Epoch 51, Loss: 28.9314
# Epoch 52, Loss: 28.2171
# Epoch 53, Loss: 28.9313
# Epoch 54, Loss: 28.9313
# Epoch 55, Loss: 27.8599
# Epoch 56, Loss: 27.8599
# Epoch 57, Loss: 29.2884
# Epoch 58, Loss: 28.9313
# Epoch 59, Loss: 27.8598
# Epoch 60, Loss: 27.5027
# Epoch 61, Loss: 27.5043
# Epoch 62, Loss: 29.2884
# Epoch 63, Loss: 28.5741
# Epoch 64, Loss: 28.2169
# Epoch 65, Loss: 27.5026
# Epoch 66, Loss: 28.2185
# Epoch 67, Loss: 28.9312
# Epoch 68, Loss: 28.2169
# Epoch 69, Loss: 27.8597
# Epoch 70, Loss: 28.9311
# Epoch 71, Loss: 28.5740
# Epoch 72, Loss: 27.5041
# Epoch 73, Loss: 28.9311
# Epoch 74, Loss: 28.2168
# Epoch 75, Loss: 28.5739
# Epoch 76, Loss: 27.8596
# Epoch 77, Loss: 27.8596
# Epoch 78, Loss: 28.5739
# Epoch 79, Loss: 28.2182
# Epoch 80, Loss: 28.5739
# Epoch 81, Loss: 28.2167
# Epoch 82, Loss: 28.5739
# Epoch 83, Loss: 28.5739
# Epoch 84, Loss: 28.2167
# Epoch 85, Loss: 29.2881
# Epoch 86, Loss: 27.8595
# Epoch 87, Loss: 28.5738
# Epoch 88, Loss: 28.2167
# Epoch 89, Loss: 29.2881
# Epoch 90, Loss: 28.2166
# Epoch 91, Loss: 29.6452
# Epoch 92, Loss: 28.5738
# Epoch 93, Loss: 27.1452
# Epoch 94, Loss: 28.2166
# Epoch 95, Loss: 27.8594
# Epoch 96, Loss: 27.8594
# Epoch 97, Loss: 27.8594
# Epoch 98, Loss: 27.5023
# Epoch 99, Loss: 29.2880
# Epoch 100, Loss: 27.8594

# %%
# Evaluation Function
def evaluate(loader):
    model.eval()
    y_true, y_pred = [], []
    with torch.no_grad():
        for batch in loader:
            out = model(batch.x, batch.edge_index, batch.batch)
            best_thresholds, _ = tune_thresholds(batch.y.cpu(), out.cpu()) # Pass out.cpu() to tune_thresholds
            best_thresholds = torch.tensor(best_thresholds, device=out.device) # Convert best_thresholds to a tensor
            pred = (out > best_thresholds).float()
            y_pred.append(pred.cpu())
            y_true.append(batch.y.cpu())
    y_true = torch.vstack(y_true).numpy()
    y_pred = torch.vstack(y_pred).numpy()
    print(classification_report(y_true, y_pred, target_names=['mint', 'leak', 'limit']))

# Run Evaluation
evaluate(test_loader)
# Out:
# Label 0: Best threshold = 0.00, Best f1 = 0.5455
# Label 1: Best threshold = 0.00, Best f1 = 0.2222
# Label 2: Best threshold = 0.00, Best f1 = 0.5455
# Label 0: Best threshold = 0.00, Best f1 = 0.2857
# Label 1: Best threshold = 0.00, Best f1 = 0.2857
# Label 2: Best threshold = 0.00, Best f1 = 0.5000
#               precision    recall  f1-score   support
#
#         mint       0.00      0.00      0.00         4
#         leak       0.00      0.00      0.00         2
#        limit       0.00      0.00      0.00         5
#
#    micro avg       0.00      0.00      0.00        11
#    macro avg       0.00      0.00      0.00        11
# weighted avg       0.00      0.00      0.00        11
#  samples avg       0.00      0.00      0.00        11
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in samples with no true labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in samples with no true nor predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
